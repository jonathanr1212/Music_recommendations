# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pickle
import numpy as np

# %%
with open('finalized_model_pca.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
def get_keys(path):
    with open("/Users/Jonathan/Documents/Flatiron/phase_5/P5_spotify_recommendations/.secret/spotify_api.json") as f:
        return json.load(f)

# %%
keys = get_keys("/Users/Jonathan/.secret/spotify_api.json")

client = keys['client']
api_key = keys['api_key']

# %%
auth_manager = SpotifyClientCredentials(client_id = client, client_secret = api_key)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# Importing data
spot_df = pd.read_csv('data/spotify_playlist.csv')
spot_df.head()
# Out:
#      artist               artist_id  popularity  \
# 0  Bon Jovi  58lV9VcRSjABbAbfWS6skp           8
# 1  Bon Jovi  58lV9VcRSjABbAbfWS6skp           0
# 2     Queen  1dfeR4HaWDbWqFHLkxsg1d          64
# 3     Queen  1dfeR4HaWDbWqFHLkxsg1d          69
# 4  Bon Jovi  58lV9VcRSjABbAbfWS6skp           0
#
#                                            album  \
# 0                              Slippery When Wet
# 1                         Bon Jovi Greatest Hits
# 2  News Of The World (Deluxe Remastered Version)
# 3  News Of The World (Deluxe Remastered Version)
# 4                                     Cross Road
#
#                                track_name                track_id  \
# 0                      Livin' On A Prayer  0J6mQxEZnlRt9ymzFntA6z
# 1                    Wanted Dead Or Alive  4Zj9VM4fO1KwkU3lFaECsW
# 2  We Are The Champions - Remastered 2011  7ccI9cStQbQdystvc6TvxD
# 3      We Will Rock You - Remastered 2011  54flyrjcdnQdco7300avMJ
# 4                You Give Love A Bad Name  7LBJui5MdjfCd8YZr4xaqA
#
#    danceability  energy  key  loudness  mode  speechiness  instrumentalness  \
# 0         0.534   0.887    0    -3.777     1       0.0345          0.000099
# 1         0.257   0.819    7    -3.562     1       0.0422          0.015000
# 2         0.268   0.459    7    -6.948     0       0.0346          0.000000
# 3         0.693   0.497    2    -7.316     1       0.1190          0.000000
# 4         0.556   0.945    0    -4.347     0       0.0496          0.000004
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.325    0.720  122.494       249293               4
# 1     0.324    0.267  150.354       308560               4
# 2     0.119    0.172   64.223       179200               4
# 3     0.258    0.473   81.308       122067               4
# 4     0.394    0.781  122.875       224307               4

# %%
def get_song(song, artist):
    
    playlist_features_list = ["artist", "artist_id", "popularity", "album", "track_name", "track_id", 
                             "danceability", "energy", "key", "loudness", "mode", "speechiness",
                             "instrumentalness", "liveness", "valence", "tempo", "duration_ms", "time_signature"]

    song_df  = pd.DataFrame(columns = playlist_features_list)
    song = sp.search(q = 'track: {},  artist: {}'.format(song, artist), limit=1)
    for track in song:
    
        playlist_features = {}
        playlist_features["artist"] = song['tracks']['items'][0]['artists'][0]['name']
        playlist_features['artist_id'] = song['tracks']['items'][0]['artists'][0]['id']
        playlist_features['popularity'] = song['tracks']['items'][0]['popularity']
        playlist_features["album"] = song['tracks']['items'][0]['album']['name']
        playlist_features["track_name"] = song['tracks']['items'][0]['name']
        playlist_features["track_id"] = song['tracks']['items'][0]['id']

        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[6:]:
            playlist_features[feature] = audio_features[feature]
        
        track_df = pd.DataFrame(playlist_features, index = [0])
        song_df = pd.concat([song_df, track_df], ignore_index = True)
        return song_df

# %%
def predict(song_title, artist, df):
    song = get_song(song_title, artist)
    new_df = pd.concat([song, spot_df], ignore_index=True)
    new_df = new_df.convert_dtypes()
    new_df_feat = new_df.select_dtypes(np.number)
    preds = model.predict(new_df_feat)
    pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components=2))]) 
    coords = pca_pipeline.fit_transform(new_df_feat)
    new_df['cluster'] = preds
    new_df['x'], new_df['y'] = [x[0] for x in coords], [x[1] for x in coords]
    cluster = new_df.loc[new_df['track_name'] == new_df['track_name'][0], 'cluster'].to_list()[0]
    new_df = new_df.loc[new_df['cluster'] == cluster]
    
    
    return new_df

# %%
def dist(row):
    x = row['x']
    y = row['y']
    distance=np.sqrt((xt-x)**2 + (yt-y)**2)
    return distance

# %%
new_df = predict('brb', 'mahalia', spot_df)

# %%
xt = new_df.loc[new_df['track_name'] == new_df['track_name'][0],'x']
yt = new_df.loc[new_df['track_name'] == new_df['track_name'][0],'y']

new_df['distance'] = new_df.apply(dist, axis =1)
new_df.sort_values('distance')[0:10]
# Out:
#               artist               artist_id  popularity  \
# 0            Mahalia  16rCzZOMQX7P8Kmn5YKexI          44
# 4160  Wynonie Harris  4Imc3wiT22cuynvQNpXcVn           0
# 6335    Norlie & KKV  2u8P7EawurNYoIzRtr5Knk          27
# 6043   A R I Z O N A  7hOGhpa8RMSuDOWntGIAJt          44
# 4847  Ritchie Valens  5Y9xEAGW4GwGJgbiI6W85P          57
# 5716   Elvis Presley  43ZHCT0cAZBISjO8DG9PnE           0
# 5505   Willie Nelson  5W5bDNCqJ1jbCgTxDD0Cb3          57
# 5371    Louis Jordan  2nRbxpnBMMbtMBWH5QdqH2          40
# 5667   Elvis Presley  43ZHCT0cAZBISjO8DG9PnE          32
# 2422            TOTO  0PFtn5NtBbbUNbU9EAmIWF          47
#
#                                               album  \
# 0                           BRB (feat. Pink Sweat$)
# 4160      More Greatest Hits - Good Rockin' Tonight
# 6335                                   seven eleven
# 6043                                        GALLERY
# 4847                                 Ritchie Valens
# 5716                                   Elvis Movies
# 5505                                 Shotgun Willie
# 5371  Jack, You're Dead: The Essential Blue Archive
# 5667                                  Elvis Is Back
# 2422         Greatest Hits: 40 Trips Around The Sun
#
#                                 track_name                track_id  \
# 0                  BRB (feat. Pink Sweat$)  3cIYfp1jvO622pUW5zaeEF
# 4160             Grandma Plays The Numbers  628ZHvFEZSdHAbp99ghlPr
# 6335                          seven eleven  1XcYiK8GMEe18whTA3h1cw
# 6043                           I Was Wrong  3a2MbZSw3NGRWHqsCJ4iQj
# 4847                     Come On, Let's Go  4cRfSR0QxDlXRHTKyEOu93
# 5716  Kissin' Cousins - 2003 Sony Remaster  0gcV8JdCeWcsU82hED7Wfy
# 5505                         Whiskey River  6gS6XQ4OqMddkgzHNz40E5
# 5371    Is You Is or Is You Ain't My Baby?  482FSFSNKIekver2drxHdv
# 5667                     It Feels So Right  5RsdY1b0JSQTGeONEYFcwm
# 2422                                Africa  6QZo2TgclkUMwJgggi8QSQ
#
#       danceability  energy  key  loudness  ...  instrumentalness  liveness  \
# 0            0.729   0.514    6    -7.815  ...          0.000085     0.093
# 4160         0.718   0.665    8   -10.369  ...          0.000675      0.11
# 6335         0.684   0.472    7    -8.512  ...               0.0    0.0889
# 6043         0.824   0.502    6     -9.38  ...            0.0559     0.105
# 4847         0.616   0.724    9    -8.101  ...          0.000003     0.128
# 5716         0.626   0.587    6     -9.98  ...               0.0      0.46
# 5505         0.581   0.574    7    -9.298  ...          0.000902     0.107
# 5371         0.808   0.304    8    -7.629  ...               0.0     0.113
# 5667          0.56   0.552   10   -11.033  ...          0.000003    0.0509
# 2422         0.682   0.584    9    -9.507  ...          0.000107    0.0468
#
#       valence    tempo  duration_ms  time_signature  cluster         x  \
# 0        0.54   79.998       218520               4        2  1.137170
# 4160    0.751   79.725       159000               4        2  1.118535
# 6335    0.655   86.984       215827               4        2  1.134607
# 6043    0.563  118.006       217293               4        2  1.207025
# 4847    0.809   81.402       124587               3        2  1.083780
# 5716    0.961   84.973       131800               4        2  1.041731
# 5505    0.853   76.915       247240               4        2  1.027522
# 5371     0.51  137.796       164587               4        2  1.207286
# 5667    0.875   84.222       128760               4        2  1.260599
# 2422    0.709   92.793       295347               4        2  1.090797
#
#              y  distance
# 0    -1.628493  0.000000
# 4160 -1.697996  0.071958
# 6335 -1.521619  0.106905
# 6043 -1.732565  0.125342
# 4847 -1.510789  0.129247
# 5716 -1.722992  0.134308
# 5505 -1.722807  0.144630
# 5371 -1.756766  0.146186
# 5667 -1.732702  0.161537
# 2422 -1.471292  0.163898
#
# [10 rows x 22 columns]
